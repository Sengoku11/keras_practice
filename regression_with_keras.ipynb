# %% [markdown]
# # Regression models with Keras
# I will use Keras Neural Network API to build a regression model.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
# Check that GPU is working
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16846354399530752790, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 6662668288
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 2355642987061210628
#  physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:09:00.0, compute capability: 6.1"]

# %% [markdown]
# ## About the data
#
# The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them.

# %%
CSV_PATH = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(CSV_PATH)
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
# Cement                1030 non-null float64
# Blast Furnace Slag    1030 non-null float64
# Fly Ash               1030 non-null float64
# Water                 1030 non-null float64
# Superplasticizer      1030 non-null float64
# Coarse Aggregate      1030 non-null float64
# Fine Aggregate        1030 non-null float64
# Age                   1030 non-null int64
# Strength              1030 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %% [markdown]
# The data looks very clean

# %% [markdown]
# ## Train test split

# %%
X = concrete_data.drop('Strength', axis=1)
y = concrete_data['Strength']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

# %% [markdown]
# ## Preprocessing

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 1.82397267,  0.52449106, -0.84805943, ..., -1.54479455,
#          0.08715809,  0.1646987 ],
#        [ 0.99378155, -0.62989123,  0.61027759, ..., -0.43182836,
#          0.8715104 , -0.68661169],
#        [-1.25999867, -0.86357185,  1.97708069, ..., -1.71582079,
#          1.3569442 , -0.28505019],
#        ...,
#        [-1.18547015,  1.97564773, -0.84805943, ...,  0.65652043,
#         -0.94423433, -0.28505019],
#        [-0.6694309 ,  2.82975041, -0.84805943, ...,  0.07347644,
#         -1.05169677, -0.28505019],
#        [-0.32886386, -0.86357185,  1.09276994, ...,  1.49610377,
#          0.32678698,  0.1646987 ]])

# %%
y_train
# Out:
# 144    72.30
# 488    22.75
# 974    15.53
# 895    49.77
# 627     7.84
#        ...
# 688     2.33
# 621    34.49
# 850    37.36
# 583    37.81
# 332    60.32
# Name: Strength, Length: 824, dtype: float64

# %% [markdown]
# ## Building a neural network

# %%
n_columns = X_train.shape[1]
print("Input columns:", n_columns)
# Out:
# Input columns: 8

# %%
def regression_model():
    model = Sequential()
    model.add(Dense(50, activation="relu", input_shape=(n_columns,)))
    model.add(Dense(50, activation="relu"))
    model.add(Dense(1))
    
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model

# %% [markdown]
# The above function create a model with two hidden layers, each of 50 units

# %%
model = regression_model()

# %%
model.fit(X_train, y_train, validation_split=0.3, epochs=200, verbose=2)
# Out:
# Train on 576 samples, validate on 248 samples
# Epoch 1/200
#  - 0s - loss: 1457.6098 - val_loss: 1607.0443
# Epoch 2/200
#  - 0s - loss: 1356.0769 - val_loss: 1476.2773
# Epoch 3/200
#  - 0s - loss: 1213.4990 - val_loss: 1282.6541
# Epoch 4/200
#  - 0s - loss: 1011.0415 - val_loss: 1027.2328
# Epoch 5/200
#  - 0s - loss: 762.2809 - val_loss: 738.5392
# Epoch 6/200
#  - 0s - loss: 511.5676 - val_loss: 478.3033
# Epoch 7/200
#  - 0s - loss: 319.5884 - val_loss: 316.3618
# Epoch 8/200
#  - 0s - loss: 225.4970 - val_loss: 259.4221
# Epoch 9/200
#  - 0s - loss: 196.8751 - val_loss: 246.4409
# Epoch 10/200
#  - 0s - loss: 187.3046 - val_loss: 238.2209
# Epoch 11/200
#  - 0s - loss: 180.4790 - val_loss: 233.1602
# Epoch 12/200
#  - 0s - loss: 174.7415 - val_loss: 227.0937
# Epoch 13/200
#  - 0s - loss: 170.5067 - val_loss: 223.1551
# Epoch 14/200
#  - 0s - loss: 166.2273 - val_loss: 217.0611
# Epoch 15/200
#  - 0s - loss: 162.7951 - val_loss: 213.2734
# Epoch 16/200
#  - 0s - loss: 159.5626 - val_loss: 208.3975
# Epoch 17/200
#  - 0s - loss: 156.5653 - val_loss: 205.8891
# Epoch 18/200
#  - 0s - loss: 154.1481 - val_loss: 202.6395
# Epoch 19/200
#  - 0s - loss: 151.3209 - val_loss: 199.3607
# Epoch 20/200
#  - 0s - loss: 149.0937 - val_loss: 197.5402
# Epoch 21/200
#  - 0s - loss: 147.1383 - val_loss: 195.7396
# Epoch 22/200
#  - 0s - loss: 144.9089 - val_loss: 191.2445
# Epoch 23/200
#  - 0s - loss: 142.9945 - val_loss: 190.0721
# Epoch 24/200
#  - 0s - loss: 141.2994 - val_loss: 188.4302
# Epoch 25/200
#  - 0s - loss: 139.5230 - val_loss: 186.3517
# Epoch 26/200
#  - 0s - loss: 138.2080 - val_loss: 182.8960
# Epoch 27/200
#  - 0s - loss: 136.7640 - val_loss: 182.9826
# Epoch 28/200
#  - 0s - loss: 135.1532 - val_loss: 180.2061
# Epoch 29/200
#  - 0s - loss: 133.6314 - val_loss: 178.5535
# Epoch 30/200
#  - 0s - loss: 132.1669 - val_loss: 177.8456
# Epoch 31/200
#  - 0s - loss: 130.9993 - val_loss: 175.7476
# Epoch 32/200
#  - 0s - loss: 129.2552 - val_loss: 173.0704
# Epoch 33/200
#  - 0s - loss: 128.2957 - val_loss: 172.0328
# Epoch 34/200
#  - 0s - loss: 126.9216 - val_loss: 171.1785
# Epoch 35/200
#  - 0s - loss: 125.8879 - val_loss: 169.4083
# Epoch 36/200
#  - 0s - loss: 124.4243 - val_loss: 166.9760
# Epoch 37/200
#  - 0s - loss: 123.3459 - val_loss: 166.0149
# Epoch 38/200
#  - 0s - loss: 122.3053 - val_loss: 165.3383
# Epoch 39/200
#  - 0s - loss: 121.6262 - val_loss: 162.7137
# Epoch 40/200
#  - 0s - loss: 119.9111 - val_loss: 162.5248
# Epoch 41/200
#  - 0s - loss: 119.0943 - val_loss: 161.2878
# Epoch 42/200
#  - 0s - loss: 117.7567 - val_loss: 159.5905
# Epoch 43/200
#  - 0s - loss: 116.8007 - val_loss: 158.7618
# Epoch 44/200
#  - 0s - loss: 115.5073 - val_loss: 157.7456
# Epoch 45/200
#  - 0s - loss: 114.6748 - val_loss: 156.5452
# Epoch 46/200
#  - 0s - loss: 113.6200 - val_loss: 154.1173
# Epoch 47/200
#  - 0s - loss: 112.6523 - val_loss: 153.6989
# Epoch 48/200
#  - 0s - loss: 111.7912 - val_loss: 153.9117
# Epoch 49/200
#  - 0s - loss: 111.5804 - val_loss: 150.7024
# Epoch 50/200
#  - 0s - loss: 110.5454 - val_loss: 150.7006
# Epoch 51/200
#  - 0s - loss: 108.9878 - val_loss: 148.8244
# Epoch 52/200
#  - 0s - loss: 107.5912 - val_loss: 149.0000
# Epoch 53/200
#  - 0s - loss: 106.7217 - val_loss: 147.4495
# Epoch 54/200
#  - 0s - loss: 105.6976 - val_loss: 144.9068
# Epoch 55/200
#  - 0s - loss: 105.4189 - val_loss: 144.6433
# Epoch 56/200
#  - 0s - loss: 103.6462 - val_loss: 142.9888
# Epoch 57/200
#  - 0s - loss: 102.7315 - val_loss: 142.5728
# Epoch 58/200
#  - 0s - loss: 101.5522 - val_loss: 140.8771
# Epoch 59/200
#  - 0s - loss: 100.6935 - val_loss: 140.0923
# Epoch 60/200
#  - 0s - loss: 99.8795 - val_loss: 138.2231
# Epoch 61/200
#  - 0s - loss: 98.1823 - val_loss: 137.1487
# Epoch 62/200
#  - 0s - loss: 97.5171 - val_loss: 135.5236
# Epoch 63/200
#  - 0s - loss: 95.7073 - val_loss: 135.7727
# Epoch 64/200
#  - 0s - loss: 94.8544 - val_loss: 132.2662
# Epoch 65/200
#  - 0s - loss: 93.2598 - val_loss: 130.8504
# Epoch 66/200
#  - 0s - loss: 92.2156 - val_loss: 130.0685
# Epoch 67/200
#  - 0s - loss: 90.5236 - val_loss: 129.2999
# Epoch 68/200
#  - 0s - loss: 89.6724 - val_loss: 124.9381
# Epoch 69/200
#  - 0s - loss: 88.0174 - val_loss: 127.2040
# Epoch 70/200
#  - 0s - loss: 86.2554 - val_loss: 125.0151
# Epoch 71/200
#  - 0s - loss: 84.5790 - val_loss: 121.2879
# Epoch 72/200
#  - 0s - loss: 83.5369 - val_loss: 119.4755
# Epoch 73/200
#  - 0s - loss: 81.5431 - val_loss: 119.9013
# Epoch 74/200
#  - 0s - loss: 80.0976 - val_loss: 117.5145
# Epoch 75/200
#  - 0s - loss: 77.8420 - val_loss: 114.4288
# Epoch 76/200
#  - 0s - loss: 76.1272 - val_loss: 112.1318
# Epoch 77/200
#  - 0s - loss: 73.9627 - val_loss: 110.7297
# Epoch 78/200
#  - 0s - loss: 72.4016 - val_loss: 109.7899
# Epoch 79/200
#  - 0s - loss: 70.3365 - val_loss: 106.4608
# Epoch 80/200
#  - 0s - loss: 69.0935 - val_loss: 103.6795
# Epoch 81/200
#  - 0s - loss: 66.8121 - val_loss: 102.6983
# Epoch 82/200
#  - 0s - loss: 65.1586 - val_loss: 100.0635
# Epoch 83/200
#  - 0s - loss: 63.9158 - val_loss: 98.9029
# Epoch 84/200
#  - 0s - loss: 62.6528 - val_loss: 96.6232
# Epoch 85/200
#  - 0s - loss: 60.0648 - val_loss: 97.0321
# Epoch 86/200
#  - 0s - loss: 58.8172 - val_loss: 93.1382
# Epoch 87/200
#  - 0s - loss: 57.3705 - val_loss: 91.9128
# Epoch 88/200
#  - 0s - loss: 56.3302 - val_loss: 90.5531
# Epoch 89/200
#  - 0s - loss: 54.4610 - val_loss: 89.2515
# Epoch 90/200
#  - 0s - loss: 53.3297 - val_loss: 88.0267
# Epoch 91/200
#  - 0s - loss: 52.1374 - val_loss: 86.4975
# Epoch 92/200
#  - 0s - loss: 51.2443 - val_loss: 86.0190
# Epoch 93/200
#  - 0s - loss: 50.2786 - val_loss: 83.1411
# Epoch 94/200
#  - 0s - loss: 49.1652 - val_loss: 83.3883
# Epoch 95/200
#  - 0s - loss: 48.3377 - val_loss: 81.6343
# Epoch 96/200
#  - 0s - loss: 47.1001 - val_loss: 82.6416
# Epoch 97/200
#  - 0s - loss: 46.5525 - val_loss: 79.8988
# Epoch 98/200
#  - 0s - loss: 45.4447 - val_loss: 77.9580
# Epoch 99/200
#  - 0s - loss: 45.0769 - val_loss: 77.6533
# Epoch 100/200
#  - 0s - loss: 44.0015 - val_loss: 78.6255
# Epoch 101/200
#  - 0s - loss: 42.8586 - val_loss: 76.7777
# Epoch 102/200
#  - 0s - loss: 42.7581 - val_loss: 75.7155
# Epoch 103/200
#  - 0s - loss: 41.5519 - val_loss: 74.4125
# Epoch 104/200
#  - 0s - loss: 41.0498 - val_loss: 74.0573
# Epoch 105/200
#  - 0s - loss: 40.5182 - val_loss: 74.4072
# Epoch 106/200
#  - 0s - loss: 39.8774 - val_loss: 72.8955
# Epoch 107/200
#  - 0s - loss: 39.5112 - val_loss: 73.7944
# Epoch 108/200
#  - 0s - loss: 38.8534 - val_loss: 71.9344
# Epoch 109/200
#  - 0s - loss: 38.2531 - val_loss: 72.2910
# Epoch 110/200
#  - 0s - loss: 38.2819 - val_loss: 71.0670
# Epoch 111/200
#  - 0s - loss: 37.4767 - val_loss: 71.2437
# Epoch 112/200
#  - 0s - loss: 37.4776 - val_loss: 69.7033
# Epoch 113/200
#  - 0s - loss: 37.3616 - val_loss: 69.9752
# Epoch 114/200
#  - 0s - loss: 36.8370 - val_loss: 71.4855
# Epoch 115/200
#  - 0s - loss: 36.5091 - val_loss: 66.9592
# Epoch 116/200
#  - 0s - loss: 35.9385 - val_loss: 67.9352
# Epoch 117/200
#  - 0s - loss: 35.1036 - val_loss: 67.7231
# Epoch 118/200
#  - 0s - loss: 34.9265 - val_loss: 67.6632
# Epoch 119/200
#  - 0s - loss: 34.4800 - val_loss: 67.1162
# Epoch 120/200
#  - 0s - loss: 33.9204 - val_loss: 65.6116
# Epoch 121/200
#  - 0s - loss: 34.1057 - val_loss: 65.7632
# Epoch 122/200
#  - 0s - loss: 33.6133 - val_loss: 65.6097
# Epoch 123/200
#  - 0s - loss: 33.7211 - val_loss: 64.2895
# Epoch 124/200
#  - 0s - loss: 33.4988 - val_loss: 64.9969
# Epoch 125/200
#  - 0s - loss: 32.2971 - val_loss: 64.0861
# Epoch 126/200
#  - 0s - loss: 32.2480 - val_loss: 63.6224
# Epoch 127/200
#  - 0s - loss: 32.3493 - val_loss: 63.3668
# Epoch 128/200
#  - 0s - loss: 32.4117 - val_loss: 62.7701
# Epoch 129/200
#  - 0s - loss: 31.8228 - val_loss: 64.2538
# Epoch 130/200
#  - 0s - loss: 32.0363 - val_loss: 61.4412
# Epoch 131/200
#  - 0s - loss: 32.3524 - val_loss: 61.9509
# Epoch 132/200
#  - 0s - loss: 31.2482 - val_loss: 62.0286
# Epoch 133/200
#  - 0s - loss: 30.9824 - val_loss: 61.9967
# Epoch 134/200
#  - 0s - loss: 31.2022 - val_loss: 64.3970
# Epoch 135/200
#  - 0s - loss: 30.7629 - val_loss: 62.3280
# Epoch 136/200
#  - 0s - loss: 30.4178 - val_loss: 61.8887
# Epoch 137/200
#  - 0s - loss: 30.4467 - val_loss: 61.8169
# Epoch 138/200
#  - 0s - loss: 30.5251 - val_loss: 60.9685
# Epoch 139/200
#  - 0s - loss: 30.1212 - val_loss: 60.6569
# Epoch 140/200
#  - 0s - loss: 29.8126 - val_loss: 59.9853
# Epoch 141/200
#  - 0s - loss: 29.5995 - val_loss: 61.5132
# Epoch 142/200
#  - 0s - loss: 29.6495 - val_loss: 59.4799
# Epoch 143/200
#  - 0s - loss: 29.5517 - val_loss: 59.9539
# Epoch 144/200
#  - 0s - loss: 29.4764 - val_loss: 62.4204
# Epoch 145/200
#  - 0s - loss: 29.4004 - val_loss: 59.6789
# Epoch 146/200
#  - 0s - loss: 29.5121 - val_loss: 58.5579
# Epoch 147/200
#  - 0s - loss: 28.8665 - val_loss: 61.2332
# Epoch 148/200
#  - 0s - loss: 28.6934 - val_loss: 58.5787
# Epoch 149/200
#  - 0s - loss: 28.5102 - val_loss: 60.1447
# Epoch 150/200
#  - 0s - loss: 28.1384 - val_loss: 60.4736
# Epoch 151/200
#  - 0s - loss: 28.2582 - val_loss: 58.7283
# Epoch 152/200
#  - 0s - loss: 29.0631 - val_loss: 58.0772
# Epoch 153/200
#  - 0s - loss: 28.1479 - val_loss: 58.6036
# Epoch 154/200
#  - 0s - loss: 28.2142 - val_loss: 58.0265
# Epoch 155/200
#  - 0s - loss: 28.0154 - val_loss: 58.3694
# Epoch 156/200
#  - 0s - loss: 27.6666 - val_loss: 61.4363
# Epoch 157/200
#  - 0s - loss: 27.5688 - val_loss: 58.9232
# Epoch 158/200
#  - 0s - loss: 27.5617 - val_loss: 57.2464
# Epoch 159/200
#  - 0s - loss: 28.4073 - val_loss: 65.7265
# Epoch 160/200
#  - 0s - loss: 28.2526 - val_loss: 57.8687
# Epoch 161/200
#  - 0s - loss: 26.9035 - val_loss: 59.5629
# Epoch 162/200
#  - 0s - loss: 26.8676 - val_loss: 56.6216
# Epoch 163/200
#  - 0s - loss: 26.5852 - val_loss: 58.9267
# Epoch 164/200
#  - 0s - loss: 26.8693 - val_loss: 57.1873
# Epoch 165/200
#  - 0s - loss: 26.4949 - val_loss: 58.1379
# Epoch 166/200
#  - 0s - loss: 26.5655 - val_loss: 57.3646
# Epoch 167/200
#  - 0s - loss: 26.3342 - val_loss: 56.8740
# Epoch 168/200
#  - 0s - loss: 26.6459 - val_loss: 59.3342
# Epoch 169/200
#  - 0s - loss: 26.8596 - val_loss: 56.2280
# Epoch 170/200
#  - 0s - loss: 26.5242 - val_loss: 59.4091
# Epoch 171/200
#  - 0s - loss: 26.7437 - val_loss: 58.6290
# Epoch 172/200
#  - 0s - loss: 25.9186 - val_loss: 57.3899
# Epoch 173/200
#  - 0s - loss: 26.0978 - val_loss: 57.7270
# Epoch 174/200
#  - 0s - loss: 25.7970 - val_loss: 56.6319
# Epoch 175/200
#  - 0s - loss: 25.7431 - val_loss: 57.8854
# Epoch 176/200
#  - 0s - loss: 25.2152 - val_loss: 56.3761
# Epoch 177/200
#  - 0s - loss: 25.5974 - val_loss: 56.2264
# Epoch 178/200
#  - 0s - loss: 25.3870 - val_loss: 58.0553
# Epoch 179/200
#  - 0s - loss: 25.2172 - val_loss: 55.6751
# Epoch 180/200
#  - 0s - loss: 25.2443 - val_loss: 56.2237
# Epoch 181/200
#  - 0s - loss: 24.8212 - val_loss: 55.3609
# Epoch 182/200
#  - 0s - loss: 24.7877 - val_loss: 53.9000
# Epoch 183/200
#  - 0s - loss: 24.6181 - val_loss: 56.6364
# Epoch 184/200
#  - 0s - loss: 24.9218 - val_loss: 55.7751
# Epoch 185/200
#  - 0s - loss: 24.2191 - val_loss: 55.3803
# Epoch 186/200
#  - 0s - loss: 24.1132 - val_loss: 54.6096
# Epoch 187/200
#  - 0s - loss: 24.1925 - val_loss: 54.9438
# Epoch 188/200
#  - 0s - loss: 24.0765 - val_loss: 54.4717
# Epoch 189/200
#  - 0s - loss: 24.0951 - val_loss: 54.7045
# Epoch 190/200
#  - 0s - loss: 23.8659 - val_loss: 53.6256
# Epoch 191/200
#  - 0s - loss: 23.9373 - val_loss: 54.6566
# Epoch 192/200
#  - 0s - loss: 23.5206 - val_loss: 54.6239
# Epoch 193/200
#  - 0s - loss: 23.4474 - val_loss: 53.9601
# Epoch 194/200
#  - 0s - loss: 23.3370 - val_loss: 55.6180
# Epoch 195/200
#  - 0s - loss: 23.6528 - val_loss: 53.0401
# Epoch 196/200
#  - 0s - loss: 23.3939 - val_loss: 53.1896
# Epoch 197/200
#  - 0s - loss: 23.2832 - val_loss: 56.6478
# Epoch 198/200
#  - 0s - loss: 23.5949 - val_loss: 52.2975
# Epoch 199/200
#  - 0s - loss: 23.1770 - val_loss: 53.2793
# Epoch 200/200
#  - 0s - loss: 23.0781 - val_loss: 51.9573

# %%
y_predicted = model.predict(X_test)

# %%
mean_squared_error(y_test, y_predicted)
# Out:
# 40.74319687808315

# %% [markdown]
# Let's compare predicted and original values

# %%
for a, b in zip(y_predicted, y_test):
    print(a, b)
# Out:
# [47.632687] 35.3
# [24.11264] 21.78
# [34.101665] 31.45
# [41.4828] 43.58
# [55.335983] 59.3
# [27.49111] 26.31
# [31.059862] 37.36
# [40.25158] 35.85
# [32.208134] 36.99
# [17.54696] 13.52
# [44.468086] 41.54
# [14.459024] 7.32
# [23.591824] 27.04
# [45.307434] 50.77
# [22.668001] 19.54
# [40.208767] 33.19
# [41.910984] 24.1
# [50.76964] 49.8
# [33.959557] 31.97
# [38.232452] 43.38
# [20.60923] 20.77
# [30.576345] 31.42
# [47.055862] 33.94
# [52.21104] 46.2
# [19.673517] 24.13
# [41.432404] 32.96
# [20.863745] 24.28
# [43.481083] 39.42
# [37.45876] 42.22
# [34.145966] 42.64
# [32.605442] 33.76
# [47.10385] 52.83
# [51.170742] 41.05
# [37.247456] 43.06
# [31.701513] 25.56
# [46.87975] 48.85
# [24.53596] 6.27
# [38.424137] 42.7
# [49.57286] 55.51
# [13.570871] 9.45
# [48.140385] 50.53
# [42.54028] 49.19
# [21.397905] 21.16
# [13.237145] 13.36
# [41.691143] 53.3
# [31.49711] 30.88
# [15.204544] 14.2
# [58.654648] 44.42
# [43.72601] 54.38
# [47.646698] 44.09
# [28.471088] 21.75
# [66.49429] 54.77
# [22.987978] 16.5
# [59.96572] 60.2
# [43.984463] 41.1
# [32.63973] 26.74
# [28.235382] 33.66
# [52.630993] 53.66
# [33.13318] 26.91
# [27.642883] 24.0
# [30.502098] 29.87
# [32.63823] 31.84
# [16.884733] 13.46
# [10.506273] 9.99
# [17.320435] 15.69
# [23.59495] 23.14
# [10.35483] 10.38
# [19.289648] 13.33
# [36.038795] 32.72
# [57.204636] 44.7
# [40.66331] 25.02
# [77.19482] 79.3
# [23.824425] 21.91
# [17.005095] 20.42
# [38.032623] 39.27
# [41.519196] 44.4
# [33.057392] 33.73
# [33.89136] 42.64
# [38.994976] 41.05
# [26.722729] 24.58
# [47.114998] 51.26
# [12.332353] 11.48
# [16.25067] 17.22
# [62.227486] 68.3
# [49.27686] 51.04
# [29.642584] 26.4
# [14.2265] 14.2
# [24.178661] 29.72
# [39.030434] 36.64
# [7.495717] 4.78
# [21.357365] 19.77
# [42.3543] 39.66
# [36.50419] 32.07
# [55.088703] 41.37
# [38.858368] 36.94
# [18.644304] 15.05
# [35.997902] 39.59
# [77.19482] 79.3
# [42.048183] 31.35
# [14.1504] 12.84
# [54.93763] 60.29
# [23.005735] 20.28
# [14.556152] 12.46
# [35.96316] 38.63
# [43.14435] 48.67
# [40.97616] 36.8
# [21.69667] 24.92
# [44.1445] 52.3
# [21.436329] 19.69
# [45.68621] 41.93
# [41.44222] 40.57
# [46.08671] 40.27
# [31.252771] 23.84
# [36.381203] 37.26
# [38.557365] 45.94
# [36.902893] 39.46
# [60.83614] 57.92
# [25.952621] 29.89
# [47.43127] 54.1
# [24.987143] 23.52
# [44.917446] 37.91
# [47.279366] 33.4
# [42.338314] 49.2
# [9.314823] 10.09
# [40.51896] 33.8
# [56.955063] 62.94
# [39.116467] 39.06
# [23.251026] 24.29
# [20.292955] 16.28
# [17.059502] 14.8
# [43.317112] 24.4
# [15.969082] 13.12
# [44.26476] 48.59
# [9.60884] 10.35
# [47.68846] 52.82
# [32.206726] 32.77
# [51.885178] 57.22
# [46.4644] 52.91
# [10.603052] 11.17
# [24.277348] 23.51
# [24.821196] 27.87
# [40.351254] 39.6
# [36.51467] 44.64
# [37.40725] 40.86
# [30.411188] 27.53
# [44.02215] 43.7
# [19.911892] 17.54
# [16.041473] 14.84
# [57.684303] 45.37
# [18.905676] 15.34
# [65.82231] 65.2
# [44.524223] 43.57
# [45.073986] 47.13
# [49.001965] 51.72
# [52.12374] 52.61
# [31.299938] 34.67
# [33.243286] 28.63
# [56.464478] 67.87
# [26.383121] 26.92
# [55.260868] 61.23
# [27.552877] 17.84
# [42.788567] 37.27
# [68.1332] 66.0
# [33.957077] 24.4
# [65.86457] 56.14
# [34.254982] 31.18
# [37.57271] 39.64
# [31.583733] 37.43
# [20.014688] 19.42
# [37.449345] 43.5
# [21.890043] 17.57
# [12.601731] 6.9
# [39.98456] 39.94
# [29.956717] 39.4
# [46.536324] 52.5
# [27.920135] 23.22
# [37.09654] 31.38
# [40.314663] 37.44
# [12.305752] 9.62
# [21.628477] 22.95
# [34.190586] 21.86
# [52.849323] 52.44
# [87.031204] 54.9
# [48.117474] 51.43
# [34.580666] 33.3
# [69.937256] 71.99
# [35.016] 32.1
# [65.86457] 55.25
# [11.070867] 9.13
# [51.800503] 53.58
# [13.816323] 13.57
# [44.875015] 51.33
# [42.631554] 44.3
# [52.21977] 36.25
# [40.900616] 38.61
# [40.444244] 33.72
# [66.37063] 71.3
# [39.596733] 41.54
# [37.49811] 39.7
# [29.507711] 30.28
# [38.33505] 22.49
# [49.374115] 43.94
# [77.26885] 66.6
# [51.20775] 41.05
# [21.47226] 21.29
# [26.007954] 29.16

# %% [markdown]
# Not so precise but that model was fast and dirty.
