# %% [markdown]
# # Regression models with Keras
# I will use Keras Neural Network API to build a regression model.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Check that GPU is working
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2844000594274819444, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 6662668288
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8449685535556982453
#  physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:09:00.0, compute capability: 6.1"]

# %% [markdown]
# ## About the data
#
# The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them.

# %%
CSV_PATH = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(CSV_PATH)
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
# Cement                1030 non-null float64
# Blast Furnace Slag    1030 non-null float64
# Fly Ash               1030 non-null float64
# Water                 1030 non-null float64
# Superplasticizer      1030 non-null float64
# Coarse Aggregate      1030 non-null float64
# Fine Aggregate        1030 non-null float64
# Age                   1030 non-null int64
# Strength              1030 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %% [markdown]
# The data looks very clean

# %% [markdown]
# ## Train test split

# %%
X = concrete_data.drop('Strength', axis=1)
y = concrete_data['Strength']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

# %% [markdown]
# ## Preprocessing

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

#X_train = (X_train - X_train.mean()) / X_train.std()
#X = (X - X.mean()) / X.std()

# %%
X_train
# Out:
# array([[ 1.82397267,  0.52449106, -0.84805943, ..., -1.54479455,
#          0.08715809,  0.1646987 ],
#        [ 0.99378155, -0.62989123,  0.61027759, ..., -0.43182836,
#          0.8715104 , -0.68661169],
#        [-1.25999867, -0.86357185,  1.97708069, ..., -1.71582079,
#          1.3569442 , -0.28505019],
#        ...,
#        [-1.18547015,  1.97564773, -0.84805943, ...,  0.65652043,
#         -0.94423433, -0.28505019],
#        [-0.6694309 ,  2.82975041, -0.84805943, ...,  0.07347644,
#         -1.05169677, -0.28505019],
#        [-0.32886386, -0.86357185,  1.09276994, ...,  1.49610377,
#          0.32678698,  0.1646987 ]])

# %%
y_train
# Out:
# 144    72.30
# 488    22.75
# 974    15.53
# 895    49.77
# 627     7.84
#        ...
# 688     2.33
# 621    34.49
# 850    37.36
# 583    37.81
# 332    60.32
# Name: Strength, Length: 824, dtype: float64

# %% [markdown]
# ## Building a neural network

# %%
n_columns = X_train.shape[1]
print("Input columns:", n_columns)
# Out:
# Input columns: 8

# %%
def regression_model():
    model = Sequential()
    model.add(Dense(50, activation="relu", input_shape=(n_columns,)))
    model.add(Dense(50, activation="relu"))
    model.add(Dense(1))
    
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model

# %% [markdown]
# The above function create a model with two hidden layers, each of 50 units

# %%
model = regression_model()

# %%
model.fit(X_train, y_train, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Train on 576 samples, validate on 248 samples
# Epoch 1/100
#  - 0s - loss: 1463.3497 - val_loss: 1609.6971
# Epoch 2/100
#  - 0s - loss: 1355.0188 - val_loss: 1476.0904
# Epoch 3/100
#  - 0s - loss: 1210.7950 - val_loss: 1288.4408
# Epoch 4/100
#  - 0s - loss: 1014.1016 - val_loss: 1032.2124
# Epoch 5/100
#  - 0s - loss: 762.7237 - val_loss: 747.3810
# Epoch 6/100
#  - 0s - loss: 516.5452 - val_loss: 492.7225
# Epoch 7/100
#  - 0s - loss: 334.1922 - val_loss: 329.9197
# Epoch 8/100
#  - 0s - loss: 245.2057 - val_loss: 269.8536
# Epoch 9/100
#  - 0s - loss: 212.7997 - val_loss: 254.7220
# Epoch 10/100
#  - 0s - loss: 199.6700 - val_loss: 246.5906
# Epoch 11/100
#  - 0s - loss: 190.4087 - val_loss: 242.0433
# Epoch 12/100
#  - 0s - loss: 183.3955 - val_loss: 237.9842
# Epoch 13/100
#  - 0s - loss: 178.1038 - val_loss: 234.2495
# Epoch 14/100
#  - 0s - loss: 173.5124 - val_loss: 227.9049
# Epoch 15/100
#  - 0s - loss: 168.8549 - val_loss: 223.2834
# Epoch 16/100
#  - 0s - loss: 165.6780 - val_loss: 220.6509
# Epoch 17/100
#  - 0s - loss: 162.1366 - val_loss: 216.6332
# Epoch 18/100
#  - 0s - loss: 159.0680 - val_loss: 213.1559
# Epoch 19/100
#  - 0s - loss: 156.6412 - val_loss: 209.1689
# Epoch 20/100
#  - 0s - loss: 153.6314 - val_loss: 206.7238
# Epoch 21/100
#  - 0s - loss: 151.1956 - val_loss: 204.5094
# Epoch 22/100
#  - 0s - loss: 148.8155 - val_loss: 201.5680
# Epoch 23/100
#  - 0s - loss: 147.1846 - val_loss: 198.9625
# Epoch 24/100
#  - 0s - loss: 145.0379 - val_loss: 196.9859
# Epoch 25/100
#  - 0s - loss: 143.5814 - val_loss: 195.8935
# Epoch 26/100
#  - 0s - loss: 141.6409 - val_loss: 193.5044
# Epoch 27/100
#  - 0s - loss: 139.6872 - val_loss: 191.5705
# Epoch 28/100
#  - 0s - loss: 138.1398 - val_loss: 188.0614
# Epoch 29/100
#  - 0s - loss: 136.5269 - val_loss: 185.8833
# Epoch 30/100
#  - 0s - loss: 135.6959 - val_loss: 187.1554
# Epoch 31/100
#  - 0s - loss: 133.7786 - val_loss: 183.3881
# Epoch 32/100
#  - 0s - loss: 132.3388 - val_loss: 181.8768
# Epoch 33/100
#  - 0s - loss: 130.8600 - val_loss: 180.2466
# Epoch 34/100
#  - 0s - loss: 129.5625 - val_loss: 178.1184
# Epoch 35/100
#  - 0s - loss: 128.5222 - val_loss: 176.9210
# Epoch 36/100
#  - 0s - loss: 126.5558 - val_loss: 175.5735
# Epoch 37/100
#  - 0s - loss: 125.8333 - val_loss: 174.1765
# Epoch 38/100
#  - 0s - loss: 123.9887 - val_loss: 172.8816
# Epoch 39/100
#  - 0s - loss: 122.4679 - val_loss: 170.0885
# Epoch 40/100
#  - 0s - loss: 121.4854 - val_loss: 168.1834
# Epoch 41/100
#  - 0s - loss: 120.2074 - val_loss: 167.9458
# Epoch 42/100
#  - 0s - loss: 118.4486 - val_loss: 165.3928
# Epoch 43/100
#  - 0s - loss: 117.7563 - val_loss: 163.2968
# Epoch 44/100
#  - 0s - loss: 115.3318 - val_loss: 161.7956
# Epoch 45/100
#  - 0s - loss: 113.9561 - val_loss: 160.2939
# Epoch 46/100
#  - 0s - loss: 112.4929 - val_loss: 158.6503
# Epoch 47/100
#  - 0s - loss: 111.2070 - val_loss: 157.0154
# Epoch 48/100
#  - 0s - loss: 108.8560 - val_loss: 154.1800
# Epoch 49/100
#  - 0s - loss: 107.8262 - val_loss: 152.0105
# Epoch 50/100
#  - 0s - loss: 105.4370 - val_loss: 149.7895
# Epoch 51/100
#  - 0s - loss: 103.6108 - val_loss: 147.6814
# Epoch 52/100
#  - 0s - loss: 101.7708 - val_loss: 144.9676
# Epoch 53/100
#  - 0s - loss: 99.4982 - val_loss: 143.3903
# Epoch 54/100
#  - 0s - loss: 97.5646 - val_loss: 139.8616
# Epoch 55/100
#  - 0s - loss: 95.3486 - val_loss: 137.5755
# Epoch 56/100
#  - 0s - loss: 93.3375 - val_loss: 135.8322
# Epoch 57/100
#  - 0s - loss: 91.4097 - val_loss: 131.5249
# Epoch 58/100
#  - 0s - loss: 89.2833 - val_loss: 129.8408
# Epoch 59/100
#  - 0s - loss: 86.8916 - val_loss: 126.8387
# Epoch 60/100
#  - 0s - loss: 84.7069 - val_loss: 124.8948
# Epoch 61/100
#  - 0s - loss: 82.6835 - val_loss: 121.2312
# Epoch 62/100
#  - 0s - loss: 80.3519 - val_loss: 119.3470
# Epoch 63/100
#  - 0s - loss: 78.6595 - val_loss: 117.6893
# Epoch 64/100
#  - 0s - loss: 76.7347 - val_loss: 114.4378
# Epoch 65/100
#  - 0s - loss: 75.0729 - val_loss: 112.0269
# Epoch 66/100
#  - 0s - loss: 73.5509 - val_loss: 111.0101
# Epoch 67/100
#  - 0s - loss: 71.1709 - val_loss: 106.1574
# Epoch 68/100
#  - 0s - loss: 69.3409 - val_loss: 106.6533
# Epoch 69/100
#  - 0s - loss: 67.8852 - val_loss: 104.4270
# Epoch 70/100
#  - 0s - loss: 66.3637 - val_loss: 100.8796
# Epoch 71/100
#  - 0s - loss: 64.4551 - val_loss: 99.4345
# Epoch 72/100
#  - 0s - loss: 62.7727 - val_loss: 98.4125
# Epoch 73/100
#  - 0s - loss: 61.6483 - val_loss: 96.6856
# Epoch 74/100
#  - 0s - loss: 60.2019 - val_loss: 94.1121
# Epoch 75/100
#  - 0s - loss: 59.0128 - val_loss: 93.0658
# Epoch 76/100
#  - 0s - loss: 57.1022 - val_loss: 91.7042
# Epoch 77/100
#  - 0s - loss: 55.9860 - val_loss: 88.9321
# Epoch 78/100
#  - 0s - loss: 54.8417 - val_loss: 88.2374
# Epoch 79/100
#  - 0s - loss: 53.6303 - val_loss: 88.1993
# Epoch 80/100
#  - 0s - loss: 52.5545 - val_loss: 85.6750
# Epoch 81/100
#  - 0s - loss: 51.6157 - val_loss: 84.3133
# Epoch 82/100
#  - 0s - loss: 50.7542 - val_loss: 84.1530
# Epoch 83/100
#  - 0s - loss: 49.8225 - val_loss: 83.4962
# Epoch 84/100
#  - 0s - loss: 48.7980 - val_loss: 81.5376
# Epoch 85/100
#  - 0s - loss: 47.8733 - val_loss: 80.5060
# Epoch 86/100
#  - 0s - loss: 47.2487 - val_loss: 78.3966
# Epoch 87/100
#  - 0s - loss: 46.4494 - val_loss: 79.6918
# Epoch 88/100
#  - 0s - loss: 45.3660 - val_loss: 78.3702
# Epoch 89/100
#  - 0s - loss: 45.0414 - val_loss: 76.4374
# Epoch 90/100
#  - 0s - loss: 43.5890 - val_loss: 76.3952
# Epoch 91/100
#  - 0s - loss: 42.9490 - val_loss: 73.9511
# Epoch 92/100
#  - 0s - loss: 42.0997 - val_loss: 74.4475
# Epoch 93/100
#  - 0s - loss: 41.4820 - val_loss: 73.2767
# Epoch 94/100
#  - 0s - loss: 40.8737 - val_loss: 72.1302
# Epoch 95/100
#  - 0s - loss: 40.2724 - val_loss: 73.3450
# Epoch 96/100
#  - 0s - loss: 39.7811 - val_loss: 71.9330
# Epoch 97/100
#  - 0s - loss: 38.8949 - val_loss: 70.5842
# Epoch 98/100
#  - 0s - loss: 38.3268 - val_loss: 70.4723
# Epoch 99/100
#  - 0s - loss: 38.0441 - val_loss: 69.4758
# Epoch 100/100
#  - 0s - loss: 37.5872 - val_loss: 68.7732

# %%
y_predicted = model.predict(X_test)

# %%
mean_squared_error(y_test, y_predicted)
# Out:
# 52.28245479268069

# %% [markdown]
# Let's compare predicted and original values

# %%
for a, b in zip(y_predicted, y_test):
    print(a, b)
# Out:
# [49.214535] 35.3
# [29.363642] 21.78
# [33.287716] 31.45
# [36.916454] 43.58
# [57.342865] 59.3
# [26.985846] 26.31
# [33.8508] 37.36
# [45.938744] 35.85
# [29.94523] 36.99
# [18.863531] 13.52
# [46.0881] 41.54
# [16.085415] 7.32
# [24.086374] 27.04
# [39.696377] 50.77
# [22.504194] 19.54
# [37.7478] 33.19
# [43.201553] 24.1
# [46.925983] 49.8
# [33.353313] 31.97
# [38.685562] 43.38
# [21.344826] 20.77
# [31.145462] 31.42
# [45.31134] 33.94
# [51.80158] 46.2
# [22.86045] 24.13
# [41.029625] 32.96
# [19.476915] 24.28
# [41.02467] 39.42
# [36.3944] 42.22
# [32.538994] 42.64
# [38.08911] 33.76
# [47.565514] 52.83
# [47.186104] 41.05
# [38.317966] 43.06
# [29.317379] 25.56
# [46.288662] 48.85
# [25.499012] 6.27
# [37.578236] 42.7
# [48.73928] 55.51
# [17.117655] 9.45
# [53.846462] 50.53
# [40.93162] 49.19
# [23.096174] 21.16
# [12.078311] 13.36
# [41.904568] 53.3
# [35.138123] 30.88
# [16.431734] 14.2
# [56.369343] 44.42
# [41.925686] 54.38
# [47.570198] 44.09
# [27.099127] 21.75
# [64.72136] 54.77
# [27.045158] 16.5
# [60.28986] 60.2
# [51.19864] 41.1
# [33.99989] 26.74
# [26.657015] 33.66
# [47.148537] 53.66
# [33.619804] 26.91
# [28.379732] 24.0
# [30.331303] 29.87
# [33.196754] 31.84
# [22.150646] 13.46
# [10.151991] 9.99
# [22.855173] 15.69
# [25.328636] 23.14
# [10.678249] 10.38
# [20.036085] 13.33
# [37.168125] 32.72
# [59.37682] 44.7
# [43.420708] 25.02
# [75.09589] 79.3
# [23.058435] 21.91
# [19.565222] 20.42
# [34.845985] 39.27
# [44.296223] 44.4
# [29.129406] 33.73
# [32.474255] 42.64
# [39.82246] 41.05
# [31.786604] 24.58
# [47.832344] 51.26
